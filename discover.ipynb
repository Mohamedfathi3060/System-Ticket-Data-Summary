# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

txt_file = "Ticket Data.txt"

df = pd.read_csv(txt_file)

# %%
df.head()
# Out:
#      ORDER_NUMBER   ORDER_ID  ORDER_UNIT_ID   ACCEPTANCE_TIME  \
# 0  001-0671177/24  114680574            NaN  11/05/2024 11:00
# 1  001-0682295/24  114691514            NaN  11/05/2024 13:00
# 2  001-0670952/24  114680352            NaN  11/06/2024 08:00
# 3  001-0671369/24  114680756            NaN  11/06/2024 10:00
# 4  001-0670929/24  114680329            NaN  11/06/2024 12:00
#
#     COMPLETION_TIME  CUSTOMER_NUMBER  CUSTOMER_COUNT    ORDER_TYPE  \
# 0  11/05/2024 11:30              123               3  Short Ticket
# 1  11/05/2024 13:45              123               3  Short Ticket
# 2  11/06/2024 08:30              123               3  Short Ticket
# 3  11/06/2024 10:15              123               3  Short Ticket
# 4  11/06/2024 13:00              123               3          Task
#
#   ORDER_CLASS PROCESSING_STATUS  ... PROCESSING_END_TIME_MINIMUM  \
# 0          SK         Completed  ...            11/05/2024 11:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 38 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ORDER_NUMBER                          42 non-null     object
#  1   ORDER_ID                              42 non-null     int64
#  2   ORDER_UNIT_ID                         0 non-null      float64
#  3   ACCEPTANCE_TIME                       42 non-null     object
#  4   COMPLETION_TIME                       42 non-null     object
#  5   CUSTOMER_NUMBER                       42 non-null     int64
#  6   CUSTOMER_COUNT                        42 non-null     int64
#  7   ORDER_TYPE                            42 non-null     object
#  8   ORDER_CLASS                           42 non-null     object
#  9   PROCESSING_STATUS                     42 non-null     object
#  10  SERVICE_CATEGORY                      42 non-null     object
# ...

# %%
df['SERVICE_CATEGORY'].value_counts()
# Out:
# SERVICE_CATEGORY
# HDW     14
# SOP      6
# NTF      4
# NET      3
# KAI      3
# KAV      3
# GIGA     3
# VOD      3
# KAD      3
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['ORDER_NUMBER', 'ORDER_ID', 'ORDER_UNIT_ID', 'ACCEPTANCE_TIME',
#        'COMPLETION_TIME', 'CUSTOMER_NUMBER', 'CUSTOMER_COUNT', 'ORDER_TYPE',
#        'ORDER_CLASS', 'PROCESSING_STATUS', 'SERVICE_CATEGORY',
#        'ORDER_DESCRIPTION_1', 'ORDER_DESCRIPTION_2',
#        'ORDER_DESCRIPTION_3_MAXIMUM', 'ADDITIONAL_ORDER_DESCRIPTION_MAXIMUM',
#        'NOTE_MAXIMUM', 'PLANNING_GROUP_KB', 'COMPLETION_RESULT_KB',
#        'REFERENCE_COMPLETION_RESULT', 'COMPLETION_NOTE_MAXIMUM',
#        'NETWORK_LEVEL', 'CAUSE', 'REFERENCE_ERROR_CAUSE', 'SERVICE_PROVIDER',
#        'REFERENCE_SERVICE_PROVIDER', 'SUBUNIT_NAME',
#        'CUSTOMER_COMPLETION_TIME', 'PROCESSING_END_TIME_MAXIMUM',
#        'PROCESSING_END_TIME_MINIMUM', 'ACCEPTANCE_TIME_MINIMUM',
#        'ASSIGNMENT_TIME_MINIMUM', 'IMIL_TIME_MINIMUM', 'CUSTOMER_TIME_MINIMUM',
#        'START_TIME_MINIMUM', 'ASSIGNMENT_TIME', 'ASSIGNED_BY_NAME',
#        'ASSIGNMENT_PROCESSING_STATUS', 'ASSIGNMENT_ADDITIONAL_INFO'],
# ...

# %%
pd.set_option('display.max_columns', None)
df.sample(1)
# Out:
#       ORDER_NUMBER   ORDER_ID  ORDER_UNIT_ID   ACCEPTANCE_TIME  \
# 14  001-0671180/24  114680577            NaN  11/10/2024 11:00
#
#      COMPLETION_TIME  CUSTOMER_NUMBER  CUSTOMER_COUNT    ORDER_TYPE  \
# 14  11/10/2024 11:30              789               2  Short Ticket
#
#    ORDER_CLASS PROCESSING_STATUS SERVICE_CATEGORY ORDER_DESCRIPTION_1  \
# 14          SK         Completed              HDW        Cable Router
#
#    ORDER_DESCRIPTION_2 ORDER_DESCRIPTION_3_MAXIMUM  \
# 14                WLAN                      Stable
#
#    ADDITIONAL_ORDER_DESCRIPTION_MAXIMUM               NOTE_MAXIMUM  \
# 14                                  NaN  WLAN Stable After Restart
#
#    PLANNING_GROUP_KB         COMPLETION_RESULT_KB REFERENCE_COMPLETION_RESULT  \
# 14             TSCW2  Router Restarted and Stable                         NaN
#
#    COMPLETION_NOTE_MAXIMUM NETWORK_LEVEL                        CAUSE  \
# 14                      OK            NZ  URS_KIP_WLAN-Settings_Reset
#
# ...

# %%
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].value_counts())
    print("\n")
# Out:
# Column: ORDER_NUMBER
# ORDER_NUMBER
# 001-0671177/24    1
# 001-0682295/24    1
# 001-0670952/24    1
# 001-0671369/24    1
# 001-0670929/24    1
# 001-0670741/24    1
# 001-0671178/24    1
# 001-0682296/24    1
# 001-0670953/24    1
# 001-0671370/24    1
# 001-0670930/24    1
# 001-0670742/24    1
# 001-0671179/24    1
# 001-0682297/24    1
# 001-0671180/24    1
# 001-0682298/24    1
# 001-0670954/24    1
# 001-0671371/24    1
# 001-0670931/24    1
# 001-0670743/24    1
# 001-0671181/24    1
# 001-0671182/24    1
# 001-0682299/24    1
# 001-0670955/24    1
# 001-0671372/24    1
# 001-0670932/24    1
# 001-0670744/24    1
# 001-0671183/24    1
# 001-0682300/24    1
# 001-0670956/24    1
# 001-0671373/24    1
# 001-0670933/24    1
# 001-0670745/24    1
# 001-0671184/24    1
# 001-0682301/24    1
# 001-0671185/24    1
# 001-0682302/24    1
# 001-0670957/24    1
# 001-0671374/24    1
# 001-0670934/24    1
# 001-0670746/24    1
# 001-0671186/24    1
# Name: count, dtype: int64
#
#
# ...

# %%
df['CUSTOMER_NUMBER'].value_counts()
# Out:
# CUSTOMER_NUMBER
# 123    14
# 456    14
# 789    14
# Name: count, dtype: int64

# %%
df[df['CUSTOMER_NUMBER'] == 123].sort_values('ACCEPTANCE_TIME')
# Out:
#       ORDER_NUMBER   ORDER_ID  ORDER_UNIT_ID   ACCEPTANCE_TIME  \
# 0   001-0671177/24  114680574            NaN  11/05/2024 11:00
# 1   001-0682295/24  114691514            NaN  11/05/2024 13:00
# 2   001-0670952/24  114680352            NaN  11/06/2024 08:00
# 3   001-0671369/24  114680756            NaN  11/06/2024 10:00
# 4   001-0670929/24  114680329            NaN  11/06/2024 12:00
# 5   001-0670741/24  114680146            NaN  11/07/2024 09:00
# 6   001-0671178/24  114680575            NaN  11/07/2024 11:00
# 21  001-0671182/24  114680579            NaN  11/13/2024 10:00
# 22  001-0682299/24  114691518            NaN  11/13/2024 12:00
# 23  001-0670955/24  114680355            NaN  11/14/2024 08:00
# 24  001-0671372/24  114680759            NaN  11/14/2024 10:00
# 26  001-0670744/24  114680149            NaN  11/15/2024 09:00
# 25  001-0670932/24  114680332            NaN  11/15/2024 12:00
# 27  001-0671183/24  114680580            NaN  11/16/2024 11:00
#
# ...

# %% [markdown]
# *Note Data is mixing between Germany and English*

# %%
df[(df['SERVICE_CATEGORY']=='GIGA' )].sort_values('ACCEPTANCE_TIME')
# Out:
#       ORDER_NUMBER   ORDER_ID  ORDER_UNIT_ID   ACCEPTANCE_TIME  \
# 32  001-0670745/24  114680150            NaN  11/14/2024 09:00
# 25  001-0670932/24  114680332            NaN  11/15/2024 12:00
# 39  001-0670934/24  114680334            NaN  11/19/2024 12:00
#
#      COMPLETION_TIME  CUSTOMER_NUMBER  CUSTOMER_COUNT    ORDER_TYPE  \
# 32  11/14/2024 09:15              456               4  Short Ticket
# 25  11/15/2024 13:00              123               3       Aufgabe
# 39  11/19/2024 13:00              789               2          Task
#
#    ORDER_CLASS PROCESSING_STATUS SERVICE_CATEGORY ORDER_DESCRIPTION_1  \
# 32          SK         Completed             GIGA      Gigabit Option
# 25          SK                ab             GIGA      Gigabit Option
# 39          SK         Completed             GIGA      Gigabit Option
#
#            ORDER_DESCRIPTION_2 ORDER_DESCRIPTION_3_MAXIMUM  \
# 32                  Not Booked                         NaN
# ...
